# %%
import pandas as pd
import nltk


#making width of the column viewable
pd.set_option('display.max_colwidth',None)
 #read the data into a dataframe
df=pd.read_csv('training.csv', encoding = "ISO-8859-1", low_memory=False)
df.head()
# Out:
#    0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4  0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
#
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0     is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 1                           @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 2                                                                     my whole body feels itchy and like its on fire
# ...

# %%
sent=df.iloc[:,[0]]
sent.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
tweet=df.iloc[:,[5]]
tweet.head()
# Out:
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0     is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 1                           @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 2                                                                     my whole body feels itchy and like its on fire
# 3     @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.
# 4                                                                                       @Kwesidei not the whole crew

# %%
df=pd.concat([tweet,sent])
df.head()
# Out:
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D  \
# 0     is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 1                           @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 2                                                                     my whole body feels itchy and like its on fire
# 3     @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.
# 4                                                                                       @Kwesidei not the whole crew
#
#     0
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
df.columns=['Tweet','Sent']
df.head()
# Out:
#                                                                                                              Tweet  \
# 0  is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 1                        @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 2                                                                  my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.
# 4                                                                                    @Kwesidei not the whole crew
#
#    Sent
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df.apply(LabelEncoder().fit_transform)
# Out:
#            Tweet  Sent
# 0        1413730     0
# 1         159096     0
# 2        1462849     0
# 3         576979     0
# 4         164408     0
# ...          ...   ...
# 1599994  1581465     1
# 1599995  1581465     1
# 1599996  1581465     1
# 1599997  1581465     1
# 1599998  1581465     1
#
# [3199998 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
def negative_tweets(text,sentiment,n):
    #create an instance of a class
    lgr=LogisticRegression(solver='lbfgs',max_iter=2500,random_state=1234)
    cv=CountVectorizer()

    dtm=cv.fit_transform(text)

    lgr.fit(dtm,sentiment)

    coefs=lgr.coef_[0]

    features=cv.get_features_out()

    df=pd.DataFrame({'Tokens':features,'coefficients':coefs})

    return df.nsmallest(n,'coefficients')
negative_tweets(df.Tweet,df.Sent,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 19
#      16     df=pd.DataFrame({'Tokens':features,'coefficients':coefs})
#      18     return df.nsmallest(n,'coefficients')
# ---> 19 negative_tweets(df.Tweet,df.Sent,10)
#
# Cell In [15], line 8, in negative_tweets(text, sentiment, n)
#       5 lgr=LogisticRegression(solver='lbfgs',max_iter=2500,random_state=1234)
#       6 cv=CountVectorizer()
# ----> 8 dtm=cv.fit_transform(text)
#      10 lgr.fit(dtm,sentiment)
#      12 coefs=lgr.coef_[0]
#
# File c:\Program Files\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1338, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1330             warnings.warn(
#    1331                 "Upper case characters found in"
#    1332                 " vocabulary while 'lowercase'"
#    1333                 " is True. These entries will not"
# ...
